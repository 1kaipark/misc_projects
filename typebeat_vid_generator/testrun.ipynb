# %%
import subprocess
import os
import random

def create_video(img_path, audio_path, output_path):
    """
    creates video based on given inputs
    args:
        img_path: path to image
        audio_path: path to audio file
        output_path: output path of video
    """
    cmd = [
        'ffmpeg',
        '-loop', '1',
        '-i', img_path,
        '-i', audio_path,
        '-c:v', 'libx264', # video codec
        '-tune', 'stillimage', # tune codec for stillimage
        '-c:a', 'aac', # audio codec
        '-b:a', '320k', # audio bitrate
        '-pix_fmt', 'yuv420p', # pixel formate
        '-shortest', # finish when shortest stream ends
        '-vf', 'scale=1920:1080:force_original_aspect_ratio=decrease,pad=1920:1080:(ow-iw)/2:(oh-ih)/2:black', # retain original aspect ratio
        output_path
    ]

    try:
        subprocess.run(cmd, check = True)
    except subprocess.CalledProcessError as e:
        print(f"L {e}")

# %%
imgs_dir = '/Users/applelaptop/CODE/misc_projs/typebeat_vid_generator/imgs_dir'
imgs = os.listdir(imgs_dir)

img = os.path.join(imgs_dir, random.choice(imgs))

# %%
import matplotlib.pyplot as plt
import cv2 as cv
i = cv.imread(img)
plt.imshow(i)

# %%
create_video(img, 'ketamine.mp3', 'test.mp4')
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from '/Users/applelaptop/CODE/misc_projs/typebeat_vid_generator/imgs_dir/maxie.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 203401 kb/s
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 3024x2613, 25 fps, 25 tbr, 25 tbn
# [mp3 @ 0x124e04b50] Estimating duration from bitrate, this may be inaccurate
# Input #1, mp3, from 'ketamine.mp3':
#   Duration: 00:01:39.11, start: 0.000000, bitrate: 320 kb/s
#   Stream #1:0: Audio: mp3, 44100 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (mp3 (mp3float) -> aac (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118210000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x128008000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x118148000] deprecated pixel format used, make sure you did set range correctly
#     Last message repeated 1 times
# [libx264 @ 0x124f07240] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x124f07240] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x124f07240] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:-3:-3 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=2.00:0.70 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.20
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt470bg/unknown/unknown, progressive), 1920x1080, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 320 kb/s
#     Metadata:
#       encoder         : Lavc60.31.102 aac
# [out#0/mp4 @ 0x6000022cc480] video:2910kB audio:4271kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.148909%
# frame= 2477 fps= 44 q=-1.0 Lsize=    7264kB time=00:01:39.10 bitrate= 600.5kbits/s speed=1.76x
# [libx264 @ 0x124f07240] frame I:10    Avg QP:10.25  size:178313
# [libx264 @ 0x124f07240] frame P:624   Avg QP:14.67  size:  1325
# [libx264 @ 0x124f07240] frame B:1843  Avg QP: 9.68  size:   200
# [libx264 @ 0x124f07240] consecutive B-frames:  0.8%  0.1%  0.0% 99.2%
# [libx264 @ 0x124f07240] mb I  I16..4: 34.4% 44.2% 21.4%
# [libx264 @ 0x124f07240] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4:  1.6%  0.2%  0.2%  0.0%  0.0%    skip:98.0%
# [libx264 @ 0x124f07240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  2.0%  0.0%  0.0%  direct: 0.0%  skip:98.0%  L0:65.7% L1:34.1% BI: 0.2%
# [libx264 @ 0x124f07240] 8x8 transform intra:44.3% inter:86.4%
# [libx264 @ 0x124f07240] coded y,uvDC,uvAC intra: 65.3% 49.1% 41.3% inter: 0.3% 0.1% 0.0%
# [libx264 @ 0x124f07240] i16 v,h,dc,p: 98%  0%  1%  0%
# [libx264 @ 0x124f07240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 13%  9%  9% 11% 11%  9% 12% 13%
# [libx264 @ 0x124f07240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 11%  9% 10% 14% 11% 10% 10% 11%
# [libx264 @ 0x124f07240] i8c dc,h,v,p: 68% 15% 12%  5%
# [libx264 @ 0x124f07240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x124f07240] ref P L0: 61.8%  0.3% 36.3%  1.6%
# [libx264 @ 0x124f07240] ref B L0: 45.7% 54.2%  0.1%
# [libx264 @ 0x124f07240] ref B L1: 99.7%  0.3%
# [libx264 @ 0x124f07240] kb/s:240.55
# [aac @ 0x124e07230] Qavg: 1321.739
